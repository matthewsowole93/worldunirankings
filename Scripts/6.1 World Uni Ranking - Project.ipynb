# %%
# Import libraries
import pandas as pd
import numpy as np
import os

# %%
path = r'C:\Users\matth\world_uni_rankings'

# %%
df_times = pd.read_csv(os.path.join(path, '01 Data', 'timesdata.csv'), index_col = False)

# %%
df_shanghai = pd.read_csv(os.path.join(path, '01 Data', 'shanghaidata.csv'), index_col = False)

# %%
df_cwur = pd.read_csv(os.path.join(path, '01 Data', 'cwurdata.csv'), index_col = False)

# %%
# details on the time ranking data
df_times.describe()
# Out:
#           teaching     research    citations  student_staff_ratio         year
# count  2603.000000  2603.000000  2603.000000          2544.000000  2603.000000
# mean     37.801498    35.910257    60.921629            18.445283  2014.075682
# std      17.604218    21.254805    23.073219            11.458698     1.685733
# min       9.900000     2.900000     1.200000             0.600000  2011.000000
# 25%      24.700000    19.600000    45.500000            11.975000  2013.000000
# 50%      33.900000    30.500000    62.500000            16.100000  2014.000000
# 75%      46.400000    47.250000    79.050000            21.500000  2016.000000
# max      99.700000    99.400000   100.000000           162.600000  2016.000000

# %%
df_times
# Out:
#      world_rank                        university_name  \
# 0             1                     Harvard University
# 1             2     California Institute of Technology
# 2             3  Massachusetts Institute of Technology
# 3             4                    Stanford University
# 4             5                   Princeton University
# ...         ...                                    ...
# 2598    601-800                    Yeungnam University
# 2599    601-800            Yıldız Technical University
# 2600    601-800               Yokohama City University
# 2601    601-800           Yokohama National University
# 2602    601-800                     Yuan Ze University
#
#                        country  teaching international  research  citations  \
# 0     United States of America      99.7          72.4      98.7       98.8
# 1     United States of America      97.7          54.6      98.0       99.9
# ...

# %%
## checking for any null values in dataset
df_times.isnull().sum()
# Out:
# world_rank                  0
# university_name             0
# country                     0
# teaching                    0
# international               0
# research                    0
# citations                   0
# income                      0
# total_score                 0
# num_students               59
# student_staff_ratio        59
# international_students     67
# female_male_ratio         233
# year                        0
# dtype: int64

# %%
## dropping the columns I don't need as not relevant
df_times = df_times.drop(columns = ['student_staff_ratio', 'international_students', 'female_male_ratio' ])

# %%
## assigning the mean value to the num students which are blank
df_times['num_students'].fillna('23,873', inplace=True)

# %%
df_times.isnull().sum()
# Out:
# world_rank         0
# university_name    0
# country            0
# teaching           0
# international      0
# research           0
# citations          0
# income             0
# total_score        0
# num_students       0
# year               0
# dtype: int64

# %%
## number of rows and columns
df_times.shape
# Out:
# (2603, 11)

# %%
# dropping additional columns not required
df_times = df_times.drop(columns = ['international', 'research', 'citations' ])

# %%
df_times.shape
# Out:
# (2603, 8)

# %%
df_times
# Out:
#      world_rank                        university_name  \
# 0             1                     Harvard University
# 1             2     California Institute of Technology
# 2             3  Massachusetts Institute of Technology
# 3             4                    Stanford University
# 4             5                   Princeton University
# ...         ...                                    ...
# 2598    601-800                    Yeungnam University
# 2599    601-800            Yıldız Technical University
# 2600    601-800               Yokohama City University
# 2601    601-800           Yokohama National University
# 2602    601-800                     Yuan Ze University
#
#                        country  teaching income total_score num_students  year
# 0     United States of America      99.7   34.5        96.1       20,152  2011
# 1     United States of America      97.7   83.7        96.0        2,243  2011
# ...

# %%
df_times.to_csv(os.path.join(path, '01 Data', 'timedata_new.csv'))
